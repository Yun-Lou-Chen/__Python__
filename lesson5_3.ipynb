# %%
for i in range(3,13):
    print('|',end='')
    for j in range(5,18):
        # print(f' {i}*{j}={(i*j):2} |',end='')
        print(f'{i:2} * {j:<2} = {i*j:3} |',end='')
    print()
# Out:
# | 3 * 5  =  15 | 3 * 6  =  18 | 3 * 7  =  21 | 3 * 8  =  24 | 3 * 9  =  27 | 3 * 10 =  30 | 3 * 11 =  33 | 3 * 12 =  36 | 3 * 13 =  39 | 3 * 14 =  42 | 3 * 15 =  45 | 3 * 16 =  48 | 3 * 17 =  51 |
# | 4 * 5  =  20 | 4 * 6  =  24 | 4 * 7  =  28 | 4 * 8  =  32 | 4 * 9  =  36 | 4 * 10 =  40 | 4 * 11 =  44 | 4 * 12 =  48 | 4 * 13 =  52 | 4 * 14 =  56 | 4 * 15 =  60 | 4 * 16 =  64 | 4 * 17 =  68 |
# | 5 * 5  =  25 | 5 * 6  =  30 | 5 * 7  =  35 | 5 * 8  =  40 | 5 * 9  =  45 | 5 * 10 =  50 | 5 * 11 =  55 | 5 * 12 =  60 | 5 * 13 =  65 | 5 * 14 =  70 | 5 * 15 =  75 | 5 * 16 =  80 | 5 * 17 =  85 |
# | 6 * 5  =  30 | 6 * 6  =  36 | 6 * 7  =  42 | 6 * 8  =  48 | 6 * 9  =  54 | 6 * 10 =  60 | 6 * 11 =  66 | 6 * 12 =  72 | 6 * 13 =  78 | 6 * 14 =  84 | 6 * 15 =  90 | 6 * 16 =  96 | 6 * 17 = 102 |
# | 7 * 5  =  35 | 7 * 6  =  42 | 7 * 7  =  49 | 7 * 8  =  56 | 7 * 9  =  63 | 7 * 10 =  70 | 7 * 11 =  77 | 7 * 12 =  84 | 7 * 13 =  91 | 7 * 14 =  98 | 7 * 15 = 105 | 7 * 16 = 112 | 7 * 17 = 119 |
# | 8 * 5  =  40 | 8 * 6  =  48 | 8 * 7  =  56 | 8 * 8  =  64 | 8 * 9  =  72 | 8 * 10 =  80 | 8 * 11 =  88 | 8 * 12 =  96 | 8 * 13 = 104 | 8 * 14 = 112 | 8 * 15 = 120 | 8 * 16 = 128 | 8 * 17 = 136 |
# | 9 * 5  =  45 | 9 * 6  =  54 | 9 * 7  =  63 | 9 * 8  =  72 | 9 * 9  =  81 | 9 * 10 =  90 | 9 * 11 =  99 | 9 * 12 = 108 | 9 * 13 = 117 | 9 * 14 = 126 | 9 * 15 = 135 | 9 * 16 = 144 | 9 * 17 = 153 |
# |10 * 5  =  50 |10 * 6  =  60 |10 * 7  =  70 |10 * 8  =  80 |10 * 9  =  90 |10 * 10 = 100 |10 * 11 = 110 |10 * 12 = 120 |10 * 13 = 130 |10 * 14 = 140 |10 * 15 = 150 |10 * 16 = 160 |10 * 17 = 170 |
# |11 * 5  =  55 |11 * 6  =  66 |11 * 7  =  77 |11 * 8  =  88 |11 * 9  =  99 |11 * 10 = 110 |11 * 11 = 121 |11 * 12 = 132 |11 * 13 = 143 |11 * 14 = 154 |11 * 15 = 165 |11 * 16 = 176 |11 * 17 = 187 |
# |12 * 5  =  60 |12 * 6  =  72 |12 * 7  =  84 |12 * 8  =  96 |12 * 9  = 108 |12 * 10 = 120 |12 * 11 = 132 |12 * 12 = 144 |12 * 13 = 156 |12 * 14 = 168 |12 * 15 = 180 |12 * 16 = 192 |12 * 17 = 204 |

# %%
import pyinputplus as pyip
# aa= pyip.inputNum(blockRegexes=[r"[0-9]qQ$"])
aa = pyip.inputNum('input: ', allowRegexes=[r'(q)+'])
print(aa)
